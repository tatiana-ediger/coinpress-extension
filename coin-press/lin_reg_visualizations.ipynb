# %% [markdown]
# Findings from experimentation with clipping threshold w high total privacy budget
# - not clipping the ball makes the two curves nearly identical (private slightly worse becasue adding some noise)
# - for all of the following generated images of graphs to get a rough idea, using d=50, iters=30, total_budget=100, n=[2000,4000,6000,8000,10000]
#
# - clip_thresh * 2:
# ![image.png](attachment:ab8f08c1-1ad2-4206-8258-1ad36720778f.png)
#
# - clip_thresh * 1.5:
# ![image.png](attachment:b4326133-ed7f-4a08-9bc8-a36b18779785.png)
#
# - clip_thresh * 1.25:
# ![image.png](attachment:2748e5b5-b9be-44e3-ac77-99a661936805.png)
#
# - clip_thresh * 1.1:
# ![image.png](attachment:d6954ab1-287a-47e2-84d4-cc4efe6b8825.png)
#
# - normal clip_thresh:
# ![image.png](attachment:23d0e938-b9c9-4ed7-9d3a-86f54e09f64e.png)

# %% [markdown]
# Findings from experimentation with clipping threshold w high total privacy budget
#
# -not clipping the ball makes the two curves nearly identical (private slightly worse becasue adding some noise)
#
# -for all of the following generated images of graphs to get a rough idea, using d=50, iters=30, total_budget=0.5, n=[2000,4000,6000,8000,10000]
#
# - clip_thresh*2:
# ![image.png](attachment:5825ed42-33cf-420e-8179-4a6cc7c28d9d.png)
#
# - clip_thresh*1.5:
# ![image.png](attachment:bf67d385-28ac-478a-8723-b53555caff40.png)
#
# - clip_thresh*1.25:
# ![image.png](attachment:1b196e8c-76ce-4c82-8f5d-907add748a01.png)
#
# - clip_thresh*1.1:
# ![image.png](attachment:f4710523-d398-4ffb-971f-dc07bc6a2946.png)
#
# - normal clip_thresh:
# ![image.png](attachment:537b275a-47b5-4719-bde5-d67265ecf05e.png)
#
# - clip_thresh*0.5:
# ![image.png](attachment:e84fcedf-60a3-414a-807e-f60b2778b2d8.png)
#
#
# - With a lower privacy budget, having a larget clipping threshold seems to make the error explode with smaller n
